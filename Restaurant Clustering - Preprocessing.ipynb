# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler, StandardScaler


import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Read data for all business

# %%
businesses = pd.read_csv('data/yelp_business.csv')
businesses.head()
# Out:
#               business_id                        name neighborhood  \
# 0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"          NaN
# 1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"          NaN
# 2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"          NaN
# 3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"          NaN
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"          NaN
#
#                             address            city state postal_code  \
# 0        "4855 E Warner Rd, Ste B9"       Ahwatukee    AZ       85044
# 1              "3101 Washington Rd"        McMurray    PA       15317
# 2          "6025 N 27th Ave, Ste 1"         Phoenix    AZ       85017
# 3  "5000 Arizona Mills Cr, Ste 435"           Tempe    AZ       85282
# 4                    "581 Howe Ave"  Cuyahoga Falls    OH       44221
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  33.330690 -111.978599    4.0            22        1
# 1  40.291685  -80.104900    3.0            11        1
# 2  33.524903 -112.115310    1.5            18        1
# 3  33.383147 -111.964725    3.0             9        0
# 4  41.119535  -81.475690    3.5           116        1
#
#                                           categories
# 0  Dentists;General Dentistry;Health & Medical;Or...
# 1  Hair Stylists;Hair Salons;Men's Hair Salons;Bl...
# 2  Departments of Motor Vehicles;Public Services ...
# 3                            Sporting Goods;Shopping
# 4  American (New);Nightlife;Bars;Sandwiches;Ameri...

# %% [markdown]
# ### Filter restaurants

# %%
restaurants = businesses[businesses['categories'].str.contains("Restaurants")]
restaurants.head(50)
# Out:
#                 business_id                                    name  \
# 4    PfOCPjBrlQAnz__NXj9h_w              "Brick House Tavern + Tap"
# 5    o9eMRCWt5PkpLDE0gOPtcQ                               "Messina"
# 10   XOSRcvtaKc_Q5H1SAzN20A                     "East Coast Coffee"
# 14   fNMVV_ZX7CJSDWQGdOM8Nw            "Showmars Government Center"
# 15   l09JfMeQ6ynYs5MCJtrcmQ                        "Alize Catering"
# 19   Gu-xs3NIQTj3Mj2xYoN2aw             "Maxim Bakery & Restaurant"
# 25   1K4qrnfyzKzGgJPBEcJaNQ                "Chula Taberna Mexicana"
# 28   Dj0S-Oe4ytRJzMGUPgYUkw                          "Panera Bread"
# 29   gAy4LYpsScrj8POnCW6btQ                            "Toast Cafe"
# 30   nbhBRhZtdaZmMMeb2i02pg                       "Sunnyside Grill"
# 32   1_3nOM7s9WqnJWTNu2-i8Q                    "Le Bistro Balmoral"
# 33   FXHfcFVEfI1vVngW2gVOpw     "Bampot House of Tea & Board Games"
# 40   tRVx2c89coruPRwYhGTcTw                                  "Yuzu"
# 44   BnuzcebyB1AfxH0kjNWqSg              "Carrabba's Italian Grill"
# 45   rDMptJYWtnMhpQu_rRXHng                            "McDonald's"
# 46   1WBkAuQg81kokZIPMpn9Zg          "Charr An American Burger Bar"
# 50   -ooEO2YqDQVYNHnSF2BPfw                      "Restaurant Lucca"
# 52   Pd52CjgyEU3Rb8co6QfTPw               "Flight Deck Bar & Grill"
# 53   4srfPk1s8nlm1YusyDUbjg                                "Subway"
# 54   n7V4cD-KqqE3OXk0irJTyA                             "GameWorks"
# 55   c_XbaJqhm-5ycSBOkVUBmg                              "Don Taco"
# 57   spDZkD6cp0JUUm6ghIWHzA                             "Kitchen M"
# 64   EJFdWX908N8Yc2XG0Lky8A                       "River Moon Cafe"
# 68   F31RycVVooeIOp9jsXmg6g                     "The Bluebird Cafe"
# 72   iPa__LOhse-hobC2Xmp-Kw                            "McDonald's"
# 75   o1fTwfqN0sDFNpV1CkOPPg                    "Crazy Mocha Coffee"
# 76   -nHkhiuerqmfBG3v2v9O-g                     "Bruegger's Bagels"
# 80   kKx8iCJkomVQBdWHnmmOiA                  "Little Caesars Pizza"
# 81   B5EZlEDH6AVDk8tQGHAGqg                             "Villa Tap"
# 86   VXH7zXcZzXlmAVN8GSjGRQ                          "Thai Express"
# 88   YhV93k9uiMdr3FlV4FHjwA                       "Caviness Studio"
# 90   aFBCmJUYrPeol_P75QX7Jw  "Fraticelli's Authentic Italian Grill"
# 91   F0fEKpTk7gAmuSFI0KW1eQ                        "Cafe Mastrioni"
# 96   dTWfATVrBfKj7Vdn0qWVWg                        "Flavor Cuisine"
# 97   HAX1zec191t7QkT2sBZ76A              "La Isla Cuban Restaurant"
# 101  VdlPZg2NAu8t8GkdbPLecg          "Tandoori Times Indian Bistro"
# 103  c7X2SdKxVJMaOnFROO8WEg        "Finga Lickin' Caribbean Eatery"
# 104  1nhf9BPXOBFBkbRkpsFaxA                 "Mirage Grill & Lounge"
# 107  QkG3KUXwqZBW18A9k1xqCA                           "Red Lobster"
# 113  sJ0MYSAIVK28cMzh-s-NPA                         "Amaya Express"
# 116  gIVjdDWRnS1yDVpPF3oUeg                           "Pizza Pizza"
# 117  veXxt8rGY_RJPpA5QkHT9Q                                "Barrio"
# 118  T5CdfrZWw-uW9Y5L_sddqQ                  "Police Station Pizza"
# 120  5XejqzaFmtkZMstJS5Iy-w                           "D'Lish Cafe"
# 122  Wpt0sFHcPtV5MO9He7yMKQ                            "McDonald's"
# 126  WUiDaFQRZ8wKYGLvmjFjAw                          "China Buffet"
# 127  nAFI7JZEhmvUKMKSA_5Chg                             "Nesenbach"
# 128  5q6Xh-UcJa78bp6dzyaE7w                           "Duck Donuts"
# 130  MTH-AcNyWfsBa9sXp04HcQ                        "Firehouse Subs"
# 132  nigYwB_m1TQ1WosjSWi-Hw                        "Simply Burgers"
#
#                   neighborhood                                    address  \
# 4                          NaN                             "581 Howe Ave"
# 5                          NaN                           "Richterstr. 11"
# 10                         NaN                         "737 West Pike St"
# 14                      Uptown                             "600 E 4th St"
# 15          Yonge and Eglinton                            "2459 Yonge St"
# 19                         NaN            "9665 Bayview Avenue, Unit 1-4"
# 25                 Leslieville                    "1058 Gerrard Street E"
# 28                         NaN                  "38295 Chestnut Ridge Rd"
# 29                         NaN                           "2429 Hwy 160 W"
# 30                         NaN                    "2777 Steeles Avenue W"
# 32                 Ville-Marie               "305 Rue Sainte-Catherine O"
# 33                         NaN                       "201 Harbord Street"
# 40                         NaN                        "13603 Madison Ave"
# 44                         NaN                        "245 Lancaster Ave"
# 45                         NaN                     "719 E Thunderbird Rd"
# 46                         NaN            "777 E Thunderbird Rd, Ste 107"
# 50   Rosemont-La Petite-Patrie                             "12 Rue Dante"
# 52                   Southeast                    "6730 S Las Vegas Blvd"
# 53                   Southeast              "6889 S Eastern Ave, Ste 101"
# 54                   Southeast           "6587 Las Vegas Blvd S, Ste 171"
# 55                 Ville-Marie  "1855 Rue Saint Catherine Ouest, H3H 1M2"
# 57                  Unionville                        "8515 McCowan Road"
# 64               Lawrenceville                              "104 43rd St"
# 68                 Cannonmills                             "5 Canonmills"
# 72                         NaN                      "1635 E Camelback Rd"
# 75               Lawrenceville                           "4032 Butler St"
# 76                         NaN                       "5217 Clairton Blvd"
# 80                         NaN                     "10720 E Southern Ave"
# 81                     Sherman                         "2302 Packers Ave"
# 86                         NaN                        "4700 Keele Street"
# 88                         NaN                                         ""
# 90                         NaN                           "10 Vogell Road"
# 91               Spring Valley            "4250 S Rainbow Blvd, Ste 1007"
# 96                 Scarborough                     "8 Glen Watford Drive"
# 97                         NaN                 "1816 Galerea Blvd, Ste D"
# 101                        NaN               "8140 N Hayden Rd, Ste H115"
# 103                        NaN                             "2838 The Plz"
# 104         Yonge and Eglinton                    "117 Eglinton Avenue E"
# 107                        NaN                      "2810 North 75th Ave"
# 113              Downtown Core               "Eaton Centre, 220 Yonge St"
# 116                   Milliken                        "7665 Kennedy Road"
# 117                        NaN                      "2466 Fairmount Blvd"
# 118                        NaN                   "7235 Steubenville Pike"
# 120                        NaN                          "503 W Thomas Rd"
# 122                   Eastside                     "3020 E Desert Inn Rd"
# 126            University City        "8630 University Executive Park Dr"
# 127                    Rathaus                          "Dorotheenstr. 6"
# 128                   Dilworth             "1710 Kenilworth Ave, Ste 220"
# 130                        NaN              "3420 E Baseline Rd, Ste 101"
# 132                        NaN                         "1455 W Elliot Rd"
#
#                   city state postal_code   latitude   longitude  stars  \
# 4       Cuyahoga Falls    OH       44221  41.119535  -81.475690    3.5
# 5            Stuttgart    BW       70567  48.727200    9.147950    4.0
# 10             Houston    PA       15342  40.241548  -80.212815    4.5
# 14           Charlotte    NC       28202  35.221647  -80.839345    3.5
# 15             Toronto    ON     M4P 2H6  43.711399  -79.399339    3.0
# 19       Richmond Hill    ON     L4C 9V4  43.867565  -79.412662    3.5
# 25             Toronto    ON     M4M 3A6  43.669256  -79.335902    3.5
# 28              Elyria    OH       44035  41.343078  -82.067140    2.0
# 29           Fort Mill    SC       29708  35.047287  -80.990559    3.5
# 30             Toronto    ON     M3J 3K5  43.781816  -79.490433    5.0
# 32            Montreal    QC     H2X 2A1  45.506772  -73.566725    3.0
# 33             Toronto    ON     M5S 1H6  43.661582  -79.408878    4.0
# 40            Lakewood    OH       44107  41.476846  -81.786971    3.5
# 44              Frazer    PA       19355  40.041003  -75.542497    3.5
# 45             Phoenix    AZ       85022  33.607070 -112.064382    1.0
# 46             Phoenix    AZ       85022  33.607310 -112.063404    3.0
# 50            Montréal    QC     H2S 1J5  45.532896  -73.613604    4.5
# 52           Las Vegas    NV       89119  36.066914 -115.170848    4.0
# 53           Las Vegas    NV       89119  36.064652 -115.118954    2.5
# 54           Las Vegas    NV       89119  36.068259 -115.178877    3.0
# 55            Montreal    QC     H3H 1M2  45.493216  -73.580379    3.5
# 57             Markham    ON     L3P 5E5  43.867918  -79.283687    3.0
# 64          Pittsburgh    PA       15201  40.472735  -79.963265    4.0
# 68           Edinburgh   MLN     EH3 5HA  55.962444   -3.197662    4.5
# 72             Phoenix    AZ       85016  33.508765 -112.046240    3.0
# 75          Pittsburgh    PA       15201  40.469295  -79.961273    3.5
# 76          Pittsburgh    PA       15236  40.344194  -79.970963    2.5
# 80                Mesa    AZ       85209  33.394877 -111.600194    2.5
# 81             Madison    WI       53704  43.123389  -89.355390    4.0
# 86             Toronto    ON     M3J 1P3  43.774878  -79.494619    3.0
# 88             Phoenix    AZ       85001  33.449967 -112.070223    5.0
# 90       Richmond Hill    ON     L4B 3K4  43.864333  -79.382411    3.0
# 91           Las Vegas    NV       89103  36.111057 -115.241688    1.5
# 96             Toronto    ON     M1S 2C1  43.787061  -79.276166    3.0
# 97           Charlotte    NC       28270  35.137223  -80.734594    3.0
# 101         Scottsdale    AZ       85258  33.555212 -111.900456    3.5
# 103          Charlotte    NC       28205  35.236823  -80.801084    4.5
# 104            Toronto    ON     M4P 1H4  43.707465  -79.394285    2.0
# 107            Phoenix    AZ       85035  33.478735 -112.221379    2.5
# 113            Toronto    ON     M5B 2L7  43.654067  -79.380081    2.5
# 116            Markham    ON     L3R 0L7  43.841217  -79.303936    4.0
# 117  Cleveland Heights    OH       44106  41.500586  -81.592278    3.5
# 118            Oakdale    PA       15071  40.442828  -80.186293    3.0
# 120            Phoenix    AZ       85013  33.480301 -112.080586    4.0
# 122          Las Vegas    NV       89121  36.130013 -115.109310    2.0
# 126          Charlotte    NC       28262  35.306173  -80.752672    3.5
# 127          Stuttgart    BW       70173  48.775453    9.180737    2.5
# 128          Charlotte    NC       28203  35.202624  -80.844419    4.5
# 130               Mesa    AZ       85204  33.379621 -111.757160    3.5
# 132            Gilbert    AZ       85233  33.349658 -111.821238    3.0
#
#      review_count  is_open                                         categories
# 4             116        1  American (New);Nightlife;Bars;Sandwiches;Ameri...
# 5               5        1                                Italian;Restaurants
# 10              3        0  Breakfast & Brunch;Gluten-Free;Coffee & Tea;Fo...
# 14              7        1                 Restaurants;American (Traditional)
# 15             12        0                         Italian;French;Restaurants
# 19             34        1                   French;Food;Bakeries;Restaurants
# 25             39        1       Tiki Bars;Nightlife;Mexican;Restaurants;Bars
# 28              4        1                  Soup;Salad;Sandwiches;Restaurants
# 29              6        0  Food;American (Traditional);Coffee & Tea;Resta...
# 30              3        1                     Restaurants;Breakfast & Brunch
# 32              8        0  Arts & Entertainment;Festivals;Restaurants;Fre...
# 33             55        1  Coffee & Tea;Restaurants;Food;Mediterranean;Te...
# 40             78        1  Nightlife;Izakaya;Comfort Food;Cocktail Bars;A...
# 44             25        0                        Restaurants;Italian;Seafood
# 45             10        1                      Fast Food;Burgers;Restaurants
# 46            232        1                                Burgers;Restaurants
# 50             11        1                                Italian;Restaurants
# 52             13        1  Nightlife;Bars;Barbeque;Sports Bars;American (...
# 53              6        1                   Fast Food;Restaurants;Sandwiches
# 54            349        1  Arcades;Arts & Entertainment;Gastropubs;Restau...
# 55             33        1                                Restaurants;Mexican
# 57             80        1                                Restaurants;Chinese
# 64              5        0                                  Cafes;Restaurants
# 68             16        1  Breakfast & Brunch;Diners;Restaurants;Cafes;Br...
# 72             34        1                      Restaurants;Burgers;Fast Food
# 75             16        1           Restaurants;Sandwiches;Coffee & Tea;Food
# 76              5        1  Breakfast & Brunch;Bagels;Restaurants;Bakeries...
# 80              4        1                                  Restaurants;Pizza
# 81             34        1  American (Traditional);Nightlife;Dive Bars;Res...
# 86              5        1  Imported Food;Specialty Food;Thai;Ethnic Food;...
# 88              4        1  Marketing;Men's Clothing;Restaurants;Graphic D...
# 90             88        1                                Restaurants;Italian
# 91              3        0                                Italian;Restaurants
# 96              6        1                     Restaurants;Chinese;Food Court
# 97              4        0                                  Restaurants;Cuban
# 101           263        1             Restaurants;Gluten-Free;Indian;Seafood
# 103            21        1    Pizza;Food;Internet Cafes;Restaurants;Caribbean
# 104             6        0  Breakfast & Brunch;Food;Coffee & Tea;Canadian ...
# 107            37        1         American (Traditional);Restaurants;Seafood
# 113            34        1                       Indian;Restaurants;Fast Food
# 116             8        1  Italian;Chicken Wings;Fast Food;Restaurants;Pizza
# 117            97        1         Food;Restaurants;Tacos;Food Trucks;Mexican
# 118             9        0                                  Pizza;Restaurants
# 120            37        0  Vegan;American (New);Restaurants;Sandwiches;Sa...
# 122            20        1                      Restaurants;Fast Food;Burgers
# 126            76        1             Buffets;Restaurants;Sushi Bars;Chinese
# 127             7        1         Cafes;Nightlife;Wine Bars;Bars;Restaurants
# 128           373        1  Breakfast & Brunch;Food;Coffee & Tea;Donuts;Re...
# 130            82        1        Food;Delis;Fast Food;Sandwiches;Restaurants
# 132             5        0                                Burgers;Restaurants

# %% [markdown]
# ### Read other attributes of all businesses (deprecated as of now)

# %%
# business_attr = pd.read_csv('data/yelp_business_attributes.csv')

# %% [markdown]
# ### Merge filtered restaurants with above attributes

# %%
# restaurant_attr = restaurants.merge(business_attr, left_on='business_id', right_on='business_id', how = 'inner')
restaurant_attr = restaurants

# %% [markdown]
# ### Read checkin data and create weekend flag

# %%
business_checkin = pd.read_csv('data/yelp_checkin.csv')
# restaurant_checkin = pd.merge(restaurant_attr['business_id'], business_checkin, 
#          left_on = 'business_id', right_on = 'business_id', how = 'inner')
business_checkin['is_weekend'] = business_checkin['weekday'].\
                            apply(lambda x : 1 if x == 'Sat' or x == 'Sun' or x == 'Fri' else 0)

# %% [markdown]
# ### Function to create categorical variable - Morning, Afternoon, Evening, Night from time

# %%
def create_time_of_day(x):
    hour = int(x.split(':')[0])
    if 6<= hour <= 11:
        return 'Morning'
    elif 12<= hour <= 15:
        return 'Afternoon'
    elif 16<= hour <= 20:
        return 'Evening'
    elif 20<=hour <= 24 or 0<=hour<=2:
        return 'Night'
    else:
        return 'Late Night'
business_checkin['time_of_day'] = business_checkin['hour'].apply(lambda x: create_time_of_day(x))

# %% [markdown]
# ### Feature Engineering to capture different checkin patterns

# %%
#Average checkins on weekdays and weekends

feature_1 = pd.pivot_table(business_checkin, values='checkins', index=['business_id'],
                     columns=['is_weekend'], aggfunc=np.mean).reset_index()
feature_1.columns = ['business_id', 'avg_checkins_weekday', 'avg_checkins_weekend']
# feature_1

# %%
#Average checkins on different day of the week

feature_2 = pd.pivot_table(business_checkin, values='checkins', index=['business_id'],
                     columns=['weekday'], aggfunc=np.mean).reset_index()
feature_2.columns = ['business_id', 'avg_checkins_Fri', 'avg_checkins_Mon', 'avg_checkins_Sat', 'avg_checkins_Sun',
                    'avg_checkins_Thu', 'avg_checkins_Tue', 'avg_checkins_Wed']
# feature_2

# %%
#Average checkins on different time of the day

feature_3 = pd.pivot_table(business_checkin, values='checkins', index=['business_id'],
                     columns=['time_of_day'], aggfunc=np.mean).reset_index()
feature_3.columns = ['business_id', 'Avg_checkins_Afternoon', 'Avg_checkins_Evening', 'Avg_checkins_Late_Night', 
                     'Avg_checkins_Morning', 'Avg_checkins_Night']
# feature_3

# %%
#Average checkins on weekdays vs. weekends broken by different times of the day

feature_4 = pd.pivot_table(business_checkin, values='checkins', index=['business_id'],
                     columns=['is_weekend','time_of_day'], aggfunc=np.mean).reset_index()


feature_4.columns = [str(col[0])+ '_'+col[1] for col in feature_4.columns]
feature_4.rename(columns={'business_id_':'business_id'}, inplace=True)

# feature_4

# %% [markdown]
# ### Merge all features and attributes

# %%
feature_1_2 = pd.merge(feature_1, feature_2, 
         left_on = 'business_id', right_on = 'business_id', how = 'inner')
feature_1_2_3 = pd.merge(feature_1_2, feature_3, 
         left_on = 'business_id', right_on = 'business_id', how = 'inner')

feature_1_2_3_4 = pd.merge(feature_1_2_3, feature_4, 
         left_on = 'business_id', right_on = 'business_id', how = 'inner')
restaurant_attr_all = pd.merge(restaurant_attr, feature_1_2_3_4, 
         left_on = 'business_id', right_on = 'business_id', how = 'inner')

# %%
pd.set_option('display.max_columns', 200)
restaurant_attr_all.head(5)
# Out:
#               business_id                          name        neighborhood  \
# 0  PfOCPjBrlQAnz__NXj9h_w    "Brick House Tavern + Tap"                 NaN
# 1  o9eMRCWt5PkpLDE0gOPtcQ                     "Messina"                 NaN
# 2  XOSRcvtaKc_Q5H1SAzN20A           "East Coast Coffee"                 NaN
# 3  fNMVV_ZX7CJSDWQGdOM8Nw  "Showmars Government Center"              Uptown
# 4  l09JfMeQ6ynYs5MCJtrcmQ              "Alize Catering"  Yonge and Eglinton
#
#               address            city state postal_code   latitude  longitude  \
# 0      "581 Howe Ave"  Cuyahoga Falls    OH       44221  41.119535 -81.475690
# 1    "Richterstr. 11"       Stuttgart    BW       70567  48.727200   9.147950
# 2  "737 West Pike St"         Houston    PA       15342  40.241548 -80.212815
# 3      "600 E 4th St"       Charlotte    NC       28202  35.221647 -80.839345
# 4     "2459 Yonge St"         Toronto    ON     M4P 2H6  43.711399 -79.399339
#
#    stars  review_count  is_open  \
# 0    3.5           116        1
# 1    4.0             5        1
# 2    4.5             3        0
# 3    3.5             7        1
# 4    3.0            12        0
#
#                                           categories  avg_checkins_weekday  \
# 0  American (New);Nightlife;Bars;Sandwiches;Ameri...              2.666667
# 1                                Italian;Restaurants                   NaN
# 2  Breakfast & Brunch;Gluten-Free;Coffee & Tea;Fo...              1.000000
# 3                 Restaurants;American (Traditional)              1.250000
# 4                         Italian;French;Restaurants              1.000000
#
#    avg_checkins_weekend  avg_checkins_Fri  avg_checkins_Mon  avg_checkins_Sat  \
# 0              3.878049               3.5          2.700000          3.785714
# 1              1.000000               NaN               NaN          1.000000
# 2              2.000000               2.0               NaN               NaN
# 3              2.000000               2.0          1.333333               NaN
# 4              1.000000               NaN               NaN          1.000000
#
#    avg_checkins_Sun  avg_checkins_Thu  avg_checkins_Tue  avg_checkins_Wed  \
# 0          4.266667             3.125          2.444444               2.5
# 1               NaN               NaN               NaN               NaN
# 2               NaN               NaN               NaN               1.0
# 3               NaN             1.000          1.250000               1.5
# 4               NaN             1.000               NaN               1.0
#
#    Avg_checkins_Afternoon  Avg_checkins_Evening  Avg_checkins_Late_Night  \
# 0                     1.4              3.038462                     2.25
# 1                     NaN              1.000000                      NaN
# 2                     1.0              1.500000                      NaN
# 3                     1.2              1.600000                      NaN
# 4                     NaN                   NaN                     1.00
#
#    Avg_checkins_Morning  Avg_checkins_Night  0_Afternoon  0_Evening  \
# 0                   1.0            4.025641         1.25   2.090909
# 1                   NaN                 NaN          NaN        NaN
# 2                   NaN                 NaN         1.00   1.000000
# 3                   NaN                 NaN         1.25   1.250000
# 4                   NaN            1.000000          NaN        NaN
#
#    0_Late Night  0_Morning  0_Night  1_Afternoon  1_Evening  1_Late Night  \
# 0           1.0        1.0  3.47619          2.0   3.733333      2.666667
# 1           NaN        NaN      NaN          NaN   1.000000           NaN
# 2           NaN        NaN      NaN          NaN   2.000000           NaN
# 3           NaN        NaN      NaN          1.0   3.000000           NaN
# 4           1.0        NaN  1.00000          NaN        NaN           NaN
#
#    1_Morning   1_Night
# 0        1.0  4.666667
# 1        NaN       NaN
# 2        NaN       NaN
# 3        NaN       NaN
# 4        NaN  1.000000

# %% [markdown]
# ### Look at the distribution of open and closed restaurants

# %%
restaurant_attr_all['is_open'].value_counts()
# Out:
# 1    39070
# 0    13017
# Name: is_open, dtype: int64

# %% [markdown]
# ### Look at Top 5 cities with most open restaurants

# %%
restaurant_attr_all[(restaurant_attr_all['is_open'] == 1)].\
    groupby('city')['business_id'].count().reset_index().\
        sort_values('business_id', ascending = False)[:5]
# Out:
#           city  business_id
# 653    Toronto         4832
# 289  Las Vegas         3947
# 476    Phoenix         2534
# 384   Montréal         2524
# 92   Charlotte         1838

# %% [markdown]
# ### We will focus on 1 city for now. Filter open restaurants  in Toronto

# %%
city = 'Toronto'
restaurants_in_city = restaurant_attr_all[(restaurant_attr_all['is_open'] == 1) & (restaurant_attr_all['city'] == city)]

restaurants_in_city.to_csv('./data/restaurants_in_'+city+'.csv', index = False)

# %%
restaurants_in_Toronto = pd.read_csv('./data/restaurants_in_Toronto.csv')

# %% [markdown]
# ### Look at distribution of count of reviews

# %%
restaurants_in_Toronto['review_count'].describe()
# Out:
# count    4832.000000
# mean       52.530629
# std        85.135641
# min         3.000000
# 25%         9.000000
# 50%        24.000000
# 75%        60.000000
# max      1494.000000
# Name: review_count, dtype: float64

# %%
percentile_value = np.percentile(restaurants_in_Toronto['review_count'], 70)

print('Count of restaurants having reviews more than', percentile_value,':', len(restaurants_in_Toronto[restaurants_in_Toronto['review_count'] > percentile_value]))
# Out:
# Count of restaurants having reviews more than 50.0 : 1428

# %% [markdown]
# ### Identify Top 30 popular cuisines

# %%
from collections import Counter

all_categories = restaurants_in_Toronto['categories'].apply(lambda x: x.split(';')).tolist()
all_categories_flat_list = [item for sublist in all_categories for item in sublist]

category_counts = Counter(all_categories_flat_list)
print(category_counts.most_common(30))
# Out:
# [('Restaurants', 4832), ('Food', 1086), ('Nightlife', 683), ('Bars', 667), ('Sandwiches', 465), ('Breakfast & Brunch', 427), ('Canadian (New)', 413), ('Cafes', 401), ('Chinese', 388), ('Coffee & Tea', 374), ('Pizza', 369), ('Italian', 352), ('Fast Food', 346), ('Japanese', 325), ('Burgers', 293), ('American (Traditional)', 241), ('Sushi Bars', 236), ('Middle Eastern', 189), ('Indian', 180), ('Mediterranean', 179), ('Asian Fusion', 176), ('Pubs', 176), ('Mexican', 175), ('Thai', 171), ('Korean', 167), ('Seafood', 160), ('Bakeries', 158), ('Specialty Food', 157), ('Event Planning & Services', 156), ('Salad', 151)]

# %% [markdown]
# ### Create flag for different cuisines

# %%
def create_restaurant_cuisine_flag(df, cuisine):
    df_cuisine = df[df['categories'].str.contains(cuisine)][['business_id', 'cuisine_flag']]
    df_cuisine.columns = ['business_id', cuisine]
    return df_cuisine
    
restaurants_in_Toronto['cuisine_flag'] = 1
restaurants_in_Toronto_w_Nightlife = create_restaurant_cuisine_flag(restaurants_in_Toronto, 'Nightlife')
restaurants_in_Toronto_w_Bar = create_restaurant_cuisine_flag(restaurants_in_Toronto, 'Bars')
restaurants_in_Toronto_w_Canadian = create_restaurant_cuisine_flag(restaurants_in_Toronto, 'Canadian')
restaurants_in_Toronto_w_Chinese = create_restaurant_cuisine_flag(restaurants_in_Toronto, 'Chinese')
restaurants_in_Toronto_w_Italian = create_restaurant_cuisine_flag(restaurants_in_Toronto, 'Italian')
restaurants_in_Toronto_w_Japanese = create_restaurant_cuisine_flag(restaurants_in_Toronto, 'Japanese')
restaurants_in_Toronto_w_American = create_restaurant_cuisine_flag(restaurants_in_Toronto, 'American')
restaurants_in_Toronto_w_Indian = create_restaurant_cuisine_flag(restaurants_in_Toronto, 'Indian')
restaurants_in_Toronto_w_Mexican = create_restaurant_cuisine_flag(restaurants_in_Toronto, 'Mexican')
restaurants_in_Toronto_w_Thai = create_restaurant_cuisine_flag(restaurants_in_Toronto, 'Thai')

# %% [markdown]
# ### Merging cuisine flags

# %%
df_1 = pd.merge(restaurants_in_Toronto, restaurants_in_Toronto_w_Nightlife, 
         left_on = 'business_id', right_on = 'business_id', how = 'left')
df_2 = pd.merge(df_1, restaurants_in_Toronto_w_Bar, 
         left_on = 'business_id', right_on = 'business_id', how = 'left')
df_3 = pd.merge(df_2, restaurants_in_Toronto_w_Canadian, 
         left_on = 'business_id', right_on = 'business_id', how = 'left')
df_4 = pd.merge(df_3, restaurants_in_Toronto_w_Chinese, 
         left_on = 'business_id', right_on = 'business_id', how = 'left')
df_5 = pd.merge(df_4, restaurants_in_Toronto_w_Italian, 
         left_on = 'business_id', right_on = 'business_id', how = 'left')
df_6 = pd.merge(df_5, restaurants_in_Toronto_w_Japanese, 
         left_on = 'business_id', right_on = 'business_id', how = 'left')
df_7 = pd.merge(df_6, restaurants_in_Toronto_w_American, 
         left_on = 'business_id', right_on = 'business_id', how = 'left')
df_8 = pd.merge(df_7, restaurants_in_Toronto_w_Indian, 
         left_on = 'business_id', right_on = 'business_id', how = 'left')
df_9 = pd.merge(df_8, restaurants_in_Toronto_w_Mexican, 
         left_on = 'business_id', right_on = 'business_id', how = 'left')
df_10 = pd.merge(df_9, restaurants_in_Toronto_w_Thai, 
         left_on = 'business_id', right_on = 'business_id', how = 'left')

# %% [markdown]
# ### Final columms and filters

# %%
relevant_cols = ['business_id','name','stars','review_count','avg_checkins_weekday', 'avg_checkins_weekend',
                'avg_checkins_Fri', 'avg_checkins_Mon', 'avg_checkins_Sat', 'avg_checkins_Sun',
                'avg_checkins_Thu', 'avg_checkins_Tue', 'avg_checkins_Wed', 'Avg_checkins_Afternoon',
                'Avg_checkins_Evening', 'Avg_checkins_Late_Night', 'Avg_checkins_Morning', 'Avg_checkins_Night',
                '0_Afternoon', '0_Evening', '0_Late Night', '0_Morning', '0_Night', '1_Afternoon', 
                '1_Evening', '1_Late Night', '1_Morning', '1_Night',
                'Nightlife', 'Bars', 'Canadian', 'Chinese', 'Italian', 'Japanese','American', 'Indian', 
                'Mexican', 'Thai']

X = df_10.loc[:,relevant_cols]
X.fillna(0, inplace = True)

relevant_cuisines = ['Nightlife', 'Bars', 'Canadian', 'Chinese', 'Italian', 'Japanese','American', 'Indian', 
                'Mexican', 'Thai']
X['cuisines'] = X.loc[:,relevant_cuisines].sum(axis = 1)
AD = X[(X['cuisines'] > 0) & (X['review_count'] > 50)]
AD.shape
# Out:
# (936, 39)

# %% [markdown]
# ### Look at statistics and write to file

# %%
AD.reset_index(drop=True).describe()
# Out:
#             stars  review_count  avg_checkins_weekday  avg_checkins_weekend  \
# count  936.000000    936.000000            936.000000            936.000000
# mean     3.581731    143.508547              2.662704              3.728247
# std      0.500265    132.259646              1.602847              2.537196
# min      1.500000     51.000000              1.000000              1.000000
# 25%      3.500000     69.750000              1.687500              2.153846
# 50%      3.500000    100.000000              2.179144              2.886752
# 75%      4.000000    162.250000              3.080833              4.401190
# max      5.000000   1494.000000             16.151515             22.474576
#
#        avg_checkins_Fri  avg_checkins_Mon  avg_checkins_Sat  avg_checkins_Sun  \
# count        936.000000        936.000000        936.000000        936.000000
# mean           3.250028          2.545456          4.007101          3.833019
# std            2.201589          1.657061          2.906220          2.904646
# min            1.000000          0.000000          0.000000          0.000000
# 25%            1.875000          1.500000          2.166667          2.000000
# 50%            2.666667          2.095455          3.100000          3.000000
# 75%            3.846154          3.000000          4.839286          4.595023
# max           22.176471         14.583333         26.700000         28.650000
#
#        avg_checkins_Thu  avg_checkins_Tue  avg_checkins_Wed  \
# count        936.000000        936.000000        936.000000
# mean           2.852299          2.553925          2.680890
# std            1.861916          1.639898          1.755881
# min            1.000000          0.000000          0.000000
# 25%            1.696875          1.545455          1.600000
# 50%            2.300000          2.111111          2.200000
# 75%            3.339286          3.000000          3.102778
# max           16.294118         18.571429         16.250000
#
#        Avg_checkins_Afternoon  Avg_checkins_Evening  Avg_checkins_Late_Night  \
# count              936.000000            936.000000               936.000000
# mean                 1.569071              2.776539                 1.654802
# std                  1.496662              2.281397                 1.217453
# min                  0.000000              0.000000                 0.000000
# 25%                  1.000000              1.543706                 1.000000
# 50%                  1.200000              2.111111                 1.333333
# 75%                  1.750000              3.075556                 2.000000
# max                 19.750000             23.714286                10.095238
#
#        Avg_checkins_Morning  Avg_checkins_Night  0_Afternoon   0_Evening  \
# count            936.000000          936.000000   936.000000  936.000000
# mean               0.765161            3.931636     1.149658    2.120910
# std                0.733113            3.302671     1.022988    1.704251
# min                0.000000            1.000000     0.000000    0.000000
# 25%                0.000000            2.071429     1.000000    1.230769
# 50%                1.000000            2.841230     1.000000    1.677083
# 75%                1.000000            4.489865     1.500000    2.375000
# max                9.800000           31.023810    11.875000   18.300000
#
#        0_Late Night   0_Morning     0_Night  1_Afternoon   1_Evening  \
# count    936.000000  936.000000  936.000000   936.000000  936.000000
# mean       1.196448    0.486392    3.356948     1.675383    3.381395
# std        0.932491    0.751446    2.819276     2.315971    3.303212
# min        0.000000    0.000000    0.000000     0.000000    0.000000
# 25%        1.000000    0.000000    1.807143     1.000000    1.600000
# 50%        1.000000    0.000000    2.460606     1.000000    2.428571
# 75%        1.500000    1.000000    3.793750     2.000000    3.800000
# max        8.090909   15.333333   27.416667    30.250000   36.133333
#
#        1_Late Night   1_Morning     1_Night   Nightlife        Bars  \
# count    936.000000  936.000000  936.000000  936.000000  936.000000
# mean       1.866085    0.650225    4.612714    0.301282    0.430556
# std        1.779914    0.815805    4.070748    0.459060    0.495419
# min        0.000000    0.000000    1.000000    0.000000    0.000000
# 25%        1.000000    0.000000    2.272727    0.000000    0.000000
# 50%        1.400000    0.000000    3.310096    0.000000    0.000000
# 75%        2.258929    1.000000    5.555556    1.000000    1.000000
# max       13.222222    6.000000   37.555556    1.000000    1.000000
#
#          Canadian     Chinese     Italian    Japanese    American      Indian  \
# count  936.000000  936.000000  936.000000  936.000000  936.000000  936.000000
# mean     0.195513    0.108974    0.139957    0.180556    0.170940    0.055556
# std      0.396807    0.311774    0.347128    0.384855    0.376658    0.229184
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           Mexican        Thai    cuisines
# count  936.000000  936.000000  936.000000
# mean     0.070513    0.059829    1.713675
# std      0.256146    0.237297    0.902323
# min      0.000000    0.000000    1.000000
# 25%      0.000000    0.000000    1.000000
# 50%      0.000000    0.000000    1.000000
# 75%      0.000000    0.000000    2.000000
# max      1.000000    1.000000    5.000000

# %%
AD.to_csv('./data/clusteringAD.csv', index = False)
